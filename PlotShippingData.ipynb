# %%
# ! pip install netCDF4

# %%
# ! pip install matplotlib

# %%
# ! pip install xarray

# %%
# ! pip install cartopy

# %%
from netCDF4 import Dataset as netcdf 
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
! ls /Users/micheltsamados/Google\ Drive/My\ Drive/ADMINISTRATION/ShippingWeatherRescue
# Out:
# 4.Αρχείο Θησείου(net version).xlsx
# Archives
# References
# RequestDigitalArchiveNationalHistoryMuseum.docx

# %%
! ls
# Out:
# Untitled.ipynb

# %%
! ls /Users/micheltsamados/Downloads/
# Out:
# (Artech House Remote Sensing) Adrian K. Fung, K. S. Chen - Microwave Scattering and Emission Models for Users -Artech House Publishers (2009).pdf
# ***Reference Letter Request - Anthea - Oxford MSc in Energy Systems
# ***Reference Letter Request - Anthea - Oxford MSc in Energy Systems.zip
# 03afe532-133c-487c-b3f0-792acd24ccc7
# 0733-3021-1520-0450_1986_025_1793_povi_2_0_co_2.pdf
# 1*FCJYnFspbyZxbDyzQpHaGA.gif
# 1-11448_16082022012250
# 101022_6766092_Contract_Sea-ice Thickness Products Inter-comparison Exercise_SIN__XS_Reviewed.docx
# 101110332_WHITEN_ESR.pdf
# 1987-ucl-booking-form-digital-final-2.pdf
# 1987-ucl-booking-form-digital-final.pdf
# 2003_005_AR_EN.mp4
# 2019_ESA_Oceans_Ekman.pptx
# 2021jc017466-sup-0001-supporting information si-s01.docx
# 2022_clean_update.ipynb
# 2023_11 Module Assessment Spreadsheet - MAP.xlsx
# 21115440 .pdf
# 23a48292-93a4-4d19-88d9-6a406db91df8
# 26991435.pdf
# 3005659900          PROFRM0014244425001.pdf
# 497482.pdf
# ...

# %%
#load ICOADS data
# https://www.ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/ICOADS_R3.0.0_1891-01.nc
filepath='/Users/micheltsamados/Downloads/'
ds = xr.open_dataset(filepath+'ICOADS_R3.0.0_1891-01.nc')
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:  (obs: 19535)
# Coordinates:
#     time     (obs) object ...
#     lat      (obs) float32 ...
#     lon      (obs) float32 ...
# Dimensions without coordinates: obs
# Data variables: (12/75)
#     date     (obs) |S8 ...
#     crs      int32 ...
#     HR       (obs) float32 ...
#     TI       (obs) float32 ...
#     LI       (obs) float32 ...
#     DS       (obs) float32 ...
#     ...       ...
#     OP       (obs) float32 ...
#     OTV      (obs) float32 ...
#     OTZ      (obs) float32 ...
#     PUID     (obs) |S10 ...
#     UID      (obs) |S6 ...
#     IRF      (obs) float32 ...
# Attributes: (12/57)
#     ncei_template_version:     NCEI_NetCDF_Point_Template_v2.0
#     featureType:               point
#     title:                     International Comprehensive Ocean-Atmosphere D...
#     summary:                   This file contains ICOADS R3.0.0 data in netCD...
#     id:                        ICOADS_R3.0.0_1891-01
# ...

# %%
filepath
# Out:
# '/Users/micheltsamados/Downloads/'

# %%
# ! pip install wget

# %%
wget --http-user=<uid> --http-password=<password> --load-cookies mycookies.txt --save-cookies mycookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge -r --reject "index.html*" -np -e robots=off https://ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/ICOADS_R3.0.0_1891-01.nc'
# Out:
#   Cell In [70], line 1
#     wget --http-user=<uid> --http-password=<password> --load-cookies mycookies.txt --save-cookies mycookies.txt --keep-session-cookies --no-check-certificate --auth-no-challenge -r --reject "index.html*" -np -e robots=off https://ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/ICOADS_R3.0.0_1891-01.nc'
#                      ^
# SyntaxError: invalid syntax

# %%
# ! pip install nctoolkit

# %%
import nctoolkit as nc
ds = nc.open_url('https://ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/ICOADS_R3.0.0_1989-01.nc')
# ds_xr = ds.to_xarray()
# Out:
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/iris/lib/python3.8/site-packages/nctoolkit/api.py:1349, in DataSet.show_contents(self, n)
#    1348 while True:
# -> 1349     if out_inc[i]:
#    1350         break
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [78], line 2
#       1 import nctoolkit as nc
# ----> 2 ds = nc.open_url('https://ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/ICOADS_R3.0.0_1989-01.nc')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/iris/lib/python3.8/site-packages/nctoolkit/api.py:899, in open_url(x, ftp_details, wait, file_stop)
#     896 else:
#     897     new_dict = None
# --> 899 return open_data(
# ...

# %%
yearstr='1891'
monthstr='01'
urlpath='https://ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/'
# urlpath='https://www.ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/'
print(urlpath+'ICOADS_R3.0.0_'+yearstr+'-'+monthstr+'.nc')
ds2 = xr.open_dataset(urlpath+'ICOADS_R3.0.0_'+yearstr+'-'+monthstr+'.nc', decode_times=False)
# ds2 = xr.open_dataset(urlpath+'ICOADS_R3.0.0_1891-01.nc', decode_times=False)
# ds2 = xr.open_dataset(urlpath, decode_times=False)




# %%time
# url
# =
# 's3://coawst-public/testing/HadCRUT.4.6.0.0.median.nc'
# ncfile = fsspec.open(url, anon=True)
# ds2 = xr. open dataset(ncfile.open())
# Out:
# https://ncei.noaa.gov/data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/ICOADS_R3.0.0_1891-01.nc
# syntax error, unexpected WORD_WORD, expecting SCAN_ATTR or SCAN_DATASET or SCAN_ERROR
# context: <!DOCTYPE^ HTML PUBLIC "-//IETF//DTD HTML 2.0//EN"><html><head><title>403 Forbidden</title></head><body><h1>Forbidden</h1><p>You don't have permission to access /data/international-comprehensive-ocean-atmosphere/v3/archive/nrt/.ddson this server.</p></body></html>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/iris/lib/python3.8/site-packages/xarray/backends/file_manager.py:209, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     208 try:
# --> 209     file = self._cache[self._key]
#     210 except KeyError:
#
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (obs: 19535)
# Coordinates:
#     time     (obs) object ...
#     lat      (obs) float32 ...
#     lon      (obs) float32 ...
# Dimensions without coordinates: obs
# Data variables: (12/75)
#     date     (obs) |S8 ...
#     crs      int32 ...
#     HR       (obs) float32 ...
#     TI       (obs) float32 ...
#     LI       (obs) float32 ...
#     DS       (obs) float32 ...
#     ...       ...
#     OP       (obs) float32 ...
#     OTV      (obs) float32 ...
#     OTZ      (obs) float32 ...
#     PUID     (obs) |S10 ...
#     UID      (obs) |S6 ...
#     IRF      (obs) float32 ...
# Attributes: (12/57)
#     ncei_template_version:     NCEI_NetCDF_Point_Template_v2.0
#     featureType:               point
#     title:                     International Comprehensive Ocean-Atmosphere D...
#     summary:                   This file contains ICOADS R3.0.0 data in netCD...
#     id:                        ICOADS_R3.0.0_1891-01
# ...

# %%
ds.lon
# Out:
# <xarray.DataArray 'lon' (obs: 19535)>
# [19535 values with dtype=float32]
# Coordinates:
#     time     (obs) object ...
#     lat      (obs) float32 ...
#     lon      (obs) float32 ...
# Dimensions without coordinates: obs
# Attributes:
#     standard_name:  longitude
#     long_name:      Longitude
#     units:          degrees_east
#     valid_min:      0.0
#     valid_max:      359.99
#     axis:           X

# %%
fig = plt.figure(figsize=(10,8))

ax = fig.add_subplot(1,1,1, projection=ccrs.Robinson())

ax.set_global()

ax.add_feature(cfeature.COASTLINE, edgecolor="tomato")
ax.add_feature(cfeature.BORDERS, edgecolor="tomato")
ax.gridlines()

plt.scatter(x=ds.lon, y=ds.lat,
            color="dodgerblue",
            s=1,
            alpha=0.5,
            transform=ccrs.PlateCarree()) ## Important

plt.show()

# %%
#Zoomed in Mediterranean


fig = plt.figure(figsize=(10,8))

ax = fig.add_subplot(1,1,1, projection=ccrs.Robinson())

ax.set_global()

ax.add_feature(cfeature.COASTLINE, edgecolor="tomato")
ax.add_feature(cfeature.BORDERS, edgecolor="tomato")
ax.gridlines()

plt.scatter(x=ds.lon, y=ds.lat,
            color="dodgerblue",
            s=1,
            alpha=0.5,
            transform=ccrs.PlateCarree()) ## Important

lat1, lon1, lat2, lon2 = 30, 10, 50, 60
ax.set_extent([lon1, lon2, lat1, lat2], crs=ccrs.PlateCarree())

plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/iris/lib/python3.8/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/homebrew/Caskroom/miniforge/base/envs/iris/lib/python3.8/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
